# %% [markdown]
# <a href="https://colab.research.google.com/github/ancestor9/24_fall_Big-Data-Processing-coding-/blob/main/bigdata_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: https://github.com/microsoft/powerbi-desktop-samples/blob/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx 을 데이터프레임으로 읽어줘

# !pip install pandas openpyxl

import pandas as pd
path = 'https://github.com/microsoft/powerbi-desktop-samples/raw/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx'

# %%
df = pd.read_excel(path)

# %%
df.head(3)
# Out:
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
# 2  Reseller           43659003     SO43659      SO43659 - 3

# %%
# prompt: https://github.com/microsoft/powerbi-desktop-samples/blob/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx 을 데이터프레임으로 읽어줘

#!pip install pandas openpyxl

import pandas as pd

# Replace with the actual URL of your Excel file
url = "https://github.com/microsoft/powerbi-desktop-samples/raw/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx"

try:
  df = pd.read_excel(url)
  print("Excel file loaded successfully.")
except Exception as e:
  print(f"Error loading Excel file: {e}")

# Display the DataFrame (optional)
# print(df.head())
# Out:
# Excel file loaded successfully.

# %%
df
# Out:
#          Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0       Reseller           43659001     SO43659      SO43659 - 1
# 1       Reseller           43659002     SO43659      SO43659 - 2
# 2       Reseller           43659003     SO43659      SO43659 - 3
# 3       Reseller           43659004     SO43659      SO43659 - 4
# 4       Reseller           43659005     SO43659      SO43659 - 5
# ...          ...                ...         ...              ...
# 121248  Internet           75122001     SO75122      SO75122 - 1
# 121249  Internet           75122002     SO75122      SO75122 - 2
# 121250  Internet           75123001     SO75123      SO75123 - 1
# 121251  Internet           75123002     SO75123      SO75123 - 2
# 121252  Internet           75123003     SO75123      SO75123 - 3
#
# [121253 rows x 4 columns]

# %%
# prompt: https://github.com/microsoft/powerbi-desktop-samples/blob/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx 파일은 여러 시트로 구성되어 있는데 모든 시트를 읽어줘

import pandas as pd

#!pip install pandas openpyxl


# Replace with the actual URL of your Excel file
url = "https://github.com/microsoft/powerbi-desktop-samples/raw/main/AdventureWorks%20Sales%20Sample/AdventureWorks%20Sales.xlsx"

try:
  xls = pd.ExcelFile(url)
  sheet_names = xls.sheet_names

  all_sheets_data = {}
  for sheet_name in sheet_names:
    df = pd.read_excel(url, sheet_name=sheet_name)
    print(df.head())
    all_sheets_data[sheet_name] = df
    print(f"Sheet '{sheet_name}' loaded successfully.")

except Exception as e:
  print(f"Error loading Excel file: {e}")


# Access data from individual sheets
# Example:
# print(all_sheets_data['Product'])
# Out:
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
# 2  Reseller           43659003     SO43659      SO43659 - 3
# 3  Reseller           43659004     SO43659      SO43659 - 4
# 4  Reseller           43659005     SO43659      SO43659 - 5
# Sheet 'Sales Order_data' loaded successfully.
#    SalesTerritoryKey     Region        Country          Group
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America
# Sheet 'Sales Territory_data' loaded successfully.
#    SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  OrderDateKey  \
# ...

# %%
type(all_sheets_data)
# Out:
# dict

# %%
all_sheets_data.keys()
# Out:
# dict_keys(['Sales Order_data', 'Sales Territory_data', 'Sales_data', 'Reseller_data', 'Date_data', 'Product_data', 'Customer_data'])

# %%
all_sheets_data['Customer_data'].head()
# Out:
#    CustomerKey       Customer ID          Customer              City  \
# 0           -1  [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1        11000        AW00011000          Jon Yang       Rockhampton
# 2        11001        AW00011001      Eugene Huang           Seaford
# 3        11002        AW00011002      Ruben Torres            Hobart
# 4        11003        AW00011003       Christy Zhu        North Ryde
#
#      State-Province    Country-Region       Postal Code
# 0  [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1        Queensland         Australia              4700
# 2          Victoria         Australia              3198
# 3          Tasmania         Australia              7001
# 4   New South Wales         Australia              2113

# %%
type('When you look at me')
# Out:
# str

# %%
len(text.lower().split())
# Out:
# 223

# %%
# prompt: text에서 단어의 출현빈도를 사전형과 반복문으로 코드를

word_counts = {}
for word in text.lower().split():
  if word not in word_counts:
    word_counts[word] = 0
  word_counts[word] += 1

print(word_counts)
# Out:
# {'that': 2, 'arizona': 1, 'sky': 1, "burnin'": 1, 'in': 4, 'your': 1, 'eyes': 1, 'you': 4, 'look': 2, 'at': 2, 'me': 4, 'and,': 1, 'babe,': 1, 'i': 8, 'wanna': 3, 'catch': 1, 'on': 1, 'fire': 1, "it's": 1, 'buried': 1, 'my': 1, 'soul': 1, 'like': 1, 'california': 1, 'gold': 1, 'found': 1, 'the': 13, 'light': 1, "couldn't": 1, 'find': 4, 'so': 3, 'when': 7, "i'm": 3, 'all': 4, 'choked': 3, 'up': 3, 'and': 7, "can't": 3, 'words': 3, 'every': 3, 'time': 3, 'we': 5, 'say': 3, 'goodbye': 3, 'baby,': 4, 'it': 3, 'hurts': 3, 'sun': 3, 'goes': 3, 'down': 3, 'band': 3, "won't": 3, 'play': 3, "i'll": 4, 'always': 4, 'remember': 4, 'us': 4, 'this': 4, 'way': 3, 'lovers': 1, 'night': 1, 'poets': 1, "tryin'": 1, 'to': 2, 'write': 1, "don't": 2, 'know': 2, 'how': 1, 'rhyme': 1, 'but,': 1, 'damn,': 1, 'try': 1, 'but': 1, 'really': 1, "you're": 1, 'where': 1, 'go': 1, 'part': 1, 'of': 1, "that's": 1, 'will': 1, 'never': 1, 'die': 1, 'oh,': 1, 'yeah': 3, 'be': 1, 'just': 1, 'a': 1, 'memory,': 1, 'hoo
# ...

# %%
# prompt: 10명의 전화번호를 dict로 입력하는 방법 반복문으로

phone_numbers = {}
for i in range(3): # 0, 1, 2
  print(i)
  name = input(f"Enter the name of person {i+1}: ")
  phone = input(f"Enter the phone number of {name}: ")
  phone_numbers[name] = phone

print(phone_numbers)
# Out:
# 0
# Enter the name of person 1: a
# Enter the phone number of a: 1
# 1
# Enter the name of person 2: b
# Enter the phone number of b: 2
# 2
# Enter the name of person 3: c
# Enter the phone number of c: 1111
# {'a': '1', 'b': '2', 'c': '1111'}

# %%
for file in xls.sheet_names:
    print(file)
# Out:
# Sales Order_data
# Sales Territory_data
# Sales_data
# Reseller_data
# Date_data
# Product_data
# Customer_data

# %%
type(all_sheets_data)
# Out:
# dict

# %%
for sheet_name, df in all_sheets_data.items():
  print(f"Sheet '{sheet_name}':")
  print(df.head())
  print('*'*100)
# Out:
# Sheet 'Sales Order_data':
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
# 2  Reseller           43659003     SO43659      SO43659 - 3
# 3  Reseller           43659004     SO43659      SO43659 - 4
# 4  Reseller           43659005     SO43659      SO43659 - 5
# ****************************************************************************************************
# Sheet 'Sales Territory_data':
#    SalesTerritoryKey     Region        Country          Group
# 0                  1  Northwest  United States  North America
# 1                  2  Northeast  United States  North America
# 2                  3    Central  United States  North America
# 3                  4  Southwest  United States  North America
# 4                  5  Southeast  United States  North America
# ...

# %%
all_sheets_data.keys()
# Out:
# dict_keys(['Sales Order_data', 'Sales Territory_data', 'Sales_data', 'Reseller_data', 'Date_data', 'Product_data', 'Customer_data'])

# %%
all_sheets_data['Customer_data']
# Out:
#        CustomerKey       Customer ID          Customer              City  \
# 0               -1  [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1            11000        AW00011000          Jon Yang       Rockhampton
# 2            11001        AW00011001      Eugene Huang           Seaford
# 3            11002        AW00011002      Ruben Torres            Hobart
# 4            11003        AW00011003       Christy Zhu        North Ryde
# ...            ...               ...               ...               ...
# 18480        29479        AW00029479        Tommy Tang        Versailles
# 18481        29480        AW00029480         Nina Raji            London
# 18482        29481        AW00029481         Ivan Suri               Hof
# 18483        29482        AW00029482     Clayton Zhang        Saint Ouen
# 18484        29483        AW00029483     Jésus Navarro  Paris La Defense
#
#           State-Province    Country-Region       Postal Code
# ...

# %%
# prompt: 모듈을 설명하는 코드와 파일을 제시해 다오

# my_module.py
# %%writefile my_module.py

class MyModule:
  """
  다양한 유틸리티 함수를 제공하는 모듈입니다.
  """
    def greet(name):
    """이 함수는 인사말을 출력합니다."""
    print(f"Hello, {name}!")

    def add(x, y):
    """이 함수는 두 숫자를 더합니다."""
    return x + y

    def gob(x, y):
    """이 함수는 두 숫자를 더합니다."""
    return x*y
# Out:
# Overwriting my_module.py

# %%
gob(10, 2)
# Out:
# 20

# %%
#%%writefile my_script.py

# my_script.py

import my_module as mm

text = mm.greet("World")
text
# Out:
# Hello, World!

# %%
result = mm.add(5, 3)
print(result)
# Out:
# 8

# %%
my_module.greet("World")
# Out:
# Hello, World!

# %%
my_module.greet("World")
result = my_module.add(5, 3)
print(result)

# %%
# prompt: class를 사용하여 모듈을 설명하는 코드를 제시해줘

# %%writefile my_module_class.py

class MyModule:
  """
  다양한 유틸리티 함수를 제공하는 모듈입니다.
  """

  def greet(self, name):
    """
    인사말을 출력합니다.

    Args:
      name: 인사말을 받을 대상의 이름입니다.
    """
    print(f"Hello, {name}!")

  def add(self, x, y):
    """
    두 숫자를 더합니다.

    Args:
      x: 첫 번째 숫자입니다.
      y: 두 번째 숫자입니다.

    Returns:
      두 숫자의 합입니다.
    """
    return x + y
# Out:
# Overwriting my_module_class.py

# %%
import pandas as pd

# %%
import my_module_class as mc

# %%
my_module_02 = mc.MyModule()

# %%
# %whos
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# ET                     module       <module 'xml.etree.Elemen<...>ml/etree/ElementTree.py'>
# MyModule               type         <class 'my_module_class.MyModule'>
# StringIO               type         <class '_io.StringIO'>
# add                    function     <function add at 0x7e074ad2b6d0>
# all_sheets_data        dict         n=7
# all_sheets_data_list   list         n=3
# csv_file_path          str          data.csv
# csv_string             str          name,age\nAlice,25\nBob,30\n
# data                   dict         n=3
# df                     DataFrame            SalesOrderLineKey<...>121253 rows x 15 columns]
# df_from_csv            DataFrame        name  age\n0  Alice   25\n1    Bob   30
# file                   str          Customer_data
# gob                    function     <function gob at 0x7e074ad29990>
# ...

# %%
# 모듈의 인스턴스를 생성합니다.
my_module = mmc.MyModule()

# 모듈의 함수를 호출합니다.
my_module.greet("World")
result = my_module.add(5, 3)
print(result)
# Out:
# Hello, World!
# 8

# %%
from my_module_class import MyModule

# %%
m = MyModule()
m.add(4,5)
# Out:
# 9

# %%
# prompt: http프로토콜을 사용하여 server와 client 통신을 연결하는 코드를 각각 만들어줘, 아주 간단하게

# Server (server.py)
import socket

HOST = '127.0.0.1'  # Standard loopback interface address (localhost)
PORT = 65432        # Port to listen on (non-privileged ports are > 1023)

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((HOST, PORT))
    s.listen()
    conn, addr = s.accept()
    with conn:
        print('Connected by', addr)
        while True:
            data = conn.recv(1024)
            if not data: break
            print('Received', repr(data))
            conn.sendall(b'Acknowledged')


# Client (client.py)
import socket

HOST = '127.0.0.1'  # The server's hostname or IP address
PORT = 65432        # The port used by the server

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.connect((HOST, PORT))
    s.sendall(b'Hello, world')
    data = s.recv(1024)

print('Received', repr(data))

# %%
# prompt: 예외처리와 파일 입출력(다양한 데이터 변환, json, panda, xml 등) 예제 코드를 제시해줘

import json
import pandas as pd
import xml.etree.ElementTree as ET
import os
from io import StringIO # import the StringIO method from the io module

def process_data(file_path):
  """
  파일 경로를 받아 파일 형식에 따라 데이터를 처리하고 출력합니다.

  Args:
    file_path: 파일 경로입니다.
  """
  try:
    if file_path.endswith('.json'):
      with open(file_path, 'r') as f:
        data = json.load(f)
        print("JSON 데이터:")
        print(data)
    elif file_path.endswith('.csv'):
      df = pd.read_csv(file_path)
      print("CSV 데이터:")
      print(df)
    elif file_path.endswith('.xml'):
      tree = ET.parse(file_path)
      root = tree.getroot()
      print("XML 데이터:")
      print(ET.tostring(root, encoding='unicode'))
    else:
      print("지원하지 않는 파일 형식입니다.")
  except FileNotFoundError:
    print(f"파일을 찾을 수 없습니다: {file_path}")
  except json.JSONDecodeError:
    print(f"JSON 파일을 디코딩할 수 없습니다: {file_path}")
  except pd.errors.ParserError:
    print(f"CSV 파일을 파싱할 수 없습니다: {file_path}")
  except ET.ParseError:
    print(f"XML 파일을 파싱할 수 없습니다: {file_path}")


# 예시 파일 경로
json_file_path = 'data.json'
csv_file_path = 'data.csv'
xml_file_path = 'data.xml'

# 파일 처리 함수 호출
process_data(json_file_path)
process_data(csv_file_path)
process_data(xml_file_path)


# 데이터 변환 예시
data = {'name': 'John Doe', 'age': 30, 'city': 'New York'}

# Python 딕셔너리를 JSON 문자열로 변환
json_string = json.dumps(data)
print("JSON 문자열:", json_string)

# JSON 문자열을 Python 딕셔너리로 변환
python_dict = json.loads(json_string)
print("Python 딕셔너리:", python_dict)


# pandas DataFrame을 CSV 문자열로 변환
df = pd.DataFrame({'name': ['Alice', 'Bob'], 'age': [25, 30]})
csv_string = df.to_csv(index=False)
print("CSV 문자열:", csv_string)

# CSV 문자열을 pandas DataFrame으로 변환
df_from_csv = pd.read_csv(pd.compat.StringIO(csv_string))
print("DataFrame from CSV:", df_from_csv)


# XML 데이터 생성
root = ET.Element("root")
child = ET.SubElement(root, "child")
child.text = "Hello, World!"

tree = ET.ElementTree(root)
xml_string = ET.tostring(root, encoding='unicode')
print("XML 문자열:", xml_string)

# XML 문자열을 파싱하여 ElementTree 객체 생성
root_from_xml = ET.fromstring(xml_string)
print("ElementTree from XML:", root_from_xml)
# Out:
# 파일을 찾을 수 없습니다: data.json
# 파일을 찾을 수 없습니다: data.csv
# 파일을 찾을 수 없습니다: data.xml
# JSON 문자열: {"name": "John Doe", "age": 30, "city": "New York"}
# Python 딕셔너리: {'name': 'John Doe', 'age': 30, 'city': 'New York'}
# CSV 문자열: name,age
# Alice,25
# Bob,30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-299b7f381528> in <cell line: 71>()
#      69
#      70 # CSV 문자열을 pandas DataFrame으로 변환
# ---> 71 df_from_csv = pd.read_csv(pd.compat.StringIO(csv_string))
#      72 print("DataFrame from CSV:", df_from_csv)
#      73
#
# AttributeError: module 'pandas.compat' has no attribute 'StringIO'

# %%
# pandas DataFrame을 CSV 문자열로 변환
df = pd.DataFrame({'name': ['Alice', 'Bob'], 'age': [25, 30]})
csv_string = df.to_csv(index=False)
print("CSV 문자열:", csv_string)

# CSV 문자열을 pandas DataFrame으로 변환
from io import StringIO # import the StringIO method from the io module.
df_from_csv = pd.read_csv(StringIO(csv_string)) # remove pandas.compat.
print("DataFrame from CSV:", df_from_csv)
print(type(df_from_csv))
# Out:
# CSV 문자열: name,age
# Alice,25
# Bob,30
#
# DataFrame from CSV:     name  age
# 0  Alice   25
# 1    Bob   30
# <class 'pandas.core.frame.DataFrame'>

# %%
def do_local():
    spam = "local spam"
def do_nonlocal():
    nonlocal spam
    spam = "nonlocal spam"
def do_global():
    global spam
    spam = "global spam"

spam = "test spam"
# Out:
#   File "<ipython-input-16-101e07b66f1e>", line 4
#     nonlocal spam
#     ^
# SyntaxError: no binding for nonlocal 'spam' found

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    """

    """
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# hello

# %%
def scope_test():
    def do_local():
        spam = "local spam"

    def do_global():
        global spam
        spam = "global spam"

    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"

    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)
scope_test()
print("In global scope:", spam)
# Out:
# After local assignment: test spam
# After nonlocal assignment: nonlocal spam
# After global assignment: nonlocal spam
# In global scope: global spam

# %%
class Dog:

    def __init__(self, name):
        self.name = name
        self.tricks ={}    # creates a new empty list for each dog

    def add_trick(self, trick):
        self.tricks.update(trick)

# %%
d = Dog('Fido')

# %%
from dataclasses import dataclass

@dataclass
class Employee:
    name: str
    dept: str
    salary: int

# %%
john = Employee('john', 'computer lab', 1000)
john.dept

john.salary
# Out:
# 1000

# %%
d.tricks
# Out:
# ['roll over']

# %%
d.tricks
# Out:
# ['roll over']

# %%
import pandas as pd
df = pd.read_csv('/content/소상공인시장진흥공단_상가(상권)정보_서울_202406.csv'. encoding='cp949')
# Out:
# <ipython-input-2-121884090e4f>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/소상공인시장진흥공단_상가(상권)정보_서울_202406.csv')

# %%
df[df['상호명'].str.contains('벅스')]
# Out:
#                       상가업소번호           상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 28860   MA010120220807026560          제이벅스  NaN        M1    과학·기술      M112
# 46229   MA010120220808239998       벅스노래연습장  NaN        R1   예술·스포츠      R104
# 54647   MA010120220808443163          코드벅스  NaN        P1       교육      P105
# 78869   MA010120220809925502            벅스  NaN        I2       음식      I211
# 86619   MA010120220810217913          링크벅스  NaN        M1    과학·기술      M107
# 101787  MA010120220811682391         벅스노래방  NaN        R1   예술·스포츠      R104
# 108786  MA010120220811867199         스터디벅스  NaN        M1    과학·기술      M105
# 109400  MA010120220811847654          제로벅스  NaN        N1  시설관리·임대      N102
# 116824  MA010120220812128421         비주얼벅스  NaN        M1    과학·기술      M112
# 119894  MA010120220812306634         스터디벅스  NaN        R1   예술·스포츠      R102
# 131193  MA010120220812686476         벅스노래바  NaN        I2       음식      I211
# ...
