# %% [markdown]
# # **API Request**
# <img src='https://media.geeksforgeeks.org/wp-content/uploads/20230216170349/What-is-an-API.png'>
#
# >##### API(application programming interface 애플리케이션 프로그래밍 인터페이스, 응용 프로그램 프로그래밍 인터페이스)는 컴퓨터나 컴퓨터 프로그램 사이의 연결이다. 일종의 소프트웨어 인터페이스이며 다른 종류의 소프트웨어에 서비스를 제공한다.(wiki)
# >> - 1. 서로 다른 소프트웨어시스템간의 통신 (print('Hello'), document.write('Hello'), Scikit-learn의 Estimators API)
# <img src = 'https://scikit-learn.org/stable/_static/ml_map.png'>
# - https://scikit-learn.org/stable/modules/classes.html
# >> - 2. 인터넷 환경에서 특정 유형의 서버에 상주하며 일종의 데이터베이스를 조작한다
# <img src='https://miro.medium.com/v2/resize:fit:1100/format:webp/1*OcmVkcsM5BWRHrg8GC17iw.png'>
# - An API is not a database. It is an access point to an app that can access a database.

# %% [markdown]
# - https://requests.readthedocs.io/en/latest/

# %%
import requests
r = requests.get('https://api.github.com/events')
r.status_code
# Out:
# 200

# %%
r = requests.get('https://api.github.com/events')
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Date': 'Fri, 20 Sep 2024 02:00:45 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"8f93e5956c69076fe2a91a9eb7618d925754c2fe574eaa42de78e119a9648365"', 'Last-Modified': 'Fri, 20 Sep 2024 01:55:45 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '58', 'X-RateLimit-Reset': '1726801245', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '2', 'Accept-Ranges': 'bytes', 'Content-Length': '18519', 'X-GitHub-Request-Id': 'B038:222FE6:1C58668:35DBC97:66ECD74F'}

# %% [markdown]
# >>> - https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses

# %%
r.headers['content-type']
# 응답 객체 r에서 Content Type 헤더의 값으로 응답으로 전송되는 리소스의 미디어 유형
# 예를 들어, 응답 본문이 JSON 형식 (application/json)이거나 HTML 형식 (text/html) 등
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '[{"id":"42101241571","type":"PullRequestReviewEvent","actor":{"id":22070286,"login":"jneo8","display_login":"jneo8","gravatar_id":"","url":"https://api.github.com/users/jneo8","avatar_url":"https://avatars.githubusercontent.com/u/22070286?"},"repo":{"id":647535451,"name":"canonical/hardware-observer-operator","url":"https://api.github.com/repos/canonical/hardware-observer-operator"},"payload":{"action":"created","review":{"id":2317047255,"node_id":"PRR_kwDOJpibW86KG1XX","user":{"login":"jneo8","id":22070286,"node_id":"MDQ6VXNlcjIyMDcwMjg2","avatar_url":"https://avatars.githubusercontent.com/u/22070286?v=4","gravatar_id":"","url":"https://api.github.com/users/jneo8","html_url":"https://github.com/jneo8","followers_url":"https://api.github.com/users/jneo8/followers","following_url":"https://api.github.com/users/jneo8/following{/other_user}","gists_url":"https://api.github.com/users/jneo8/gists{/gist_id}","starred_url":"https://api.github.com/users/jneo8/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/jneo8/subscriptions","organizations_url":"https://api.github.com/users/jneo8/orgs","repos_url":"https://api.github.com/users/jneo8/repos","events_url":"https://api.github.com/users/jneo8/events{/privacy}","received_events_url":"https://api.github.com/users/jneo8/received_events","type":"User","site_admin":false},"body":null,"commit_id":"9358ec4e9eb021388231847c5f38d58137fd6951","submitted_at":"2024-09-20T01:55:44Z","state":"commented","html_url":"https://github.com/canonical/hardware-observer-operator/pull/319#pullrequestreview-2317047255","pull_request_url":"https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319","author_association":"CONTRIBUTOR","_links":{"html":{"href":"https://github.com/canonical/hardware-observer-operator/pull/319#pullrequestreview-2317047255"},"pull_request":{"href":"https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319"}}},"pull_request":{"url":"https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319","id":2079766989,"node_id":"PR_kwDOJpibW8579rnN","html_url":"https://github.com/canonical/hardware-observer-operator/pull/319","diff_url":"https://github.com/canonical/hardware-observer-operator/pull/319.diff","patch_url":"https://github.com/canonical/hardware-observer-operator/pull/319.patch","issue_url":"https://api.github.com/repos/canonical/hardware-observer-operator/issues/319","number":319,"state":"open","locked":false,"title":"Add SnapExporter class and DCGM","user":{"login":"gabrielcocenza","id":23260991,"node_id":"MDQ6VXNlcjIzMjYwOTkx","avatar_url":"https://avatars.githubusercontent.com/u/23260991?v=4","gravatar_id":"","url":"https://api.github.com/users/gabrielcocenza","html_url":"https://github.com/gabrielcocenza","followers_url":"https://api.github.com/users/gabrielcocenza/followers","following_url":"https://api.github.com/users/gabrielcocenza/following{/other_user}","gists_url":"https://api.github.com/users/gabrielcocenza/gists{/gist_id}","starred_url":"https://api.github.com/users/gabrielcocenza/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/gabrielcocenza/subscriptions","organizations_url":"https://api.github.com/users/gabrielcocenza/orgs","repos_url":"https://api.github.com/users/gabrielcocenza/repos","events_url":"https://api.github.com/users/gabrielcocenza/events{/privacy}","received_events_url":"https://api.github.com/users/gabrielcocenza/received_events","type":"User","site_admin":false},"body":"- Added the SnapExporter class that can be used for handle snap packages\\r\\n- Added the DCGMExporter that installs the DCGM exporter if detected NVIDIA GPUs\\r\\n- BaseExporter is a simple abstract class that has the required methods for an exporter\\r\\n- RendarableExporter is the legacy BaseExporter that contains the logic for exporters that are not snaped","created_at":"2024-09-18T23:45:55Z","updated_at":"2024-09-20T01:55:44Z","closed_at":null,"merged_at":null,"merge_commit_sha":" ...

# %%
data = r.json()
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 30

# %%
data[0]
# Out:
# {'id': '42101241571',
#  'type': 'PullRequestReviewEvent',
#  'actor': {'id': 22070286,
#   'login': 'jneo8',
#   'display_login': 'jneo8',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jneo8',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22070286?'},
#  'repo': {'id': 647535451,
#   'name': 'canonical/hardware-observer-operator',
#   'url': 'https://api.github.com/repos/canonical/hardware-observer-operator'},
#  'payload': {'action': 'created',
#   'review': {'id': 2317047255,
#    'node_id': 'PRR_kwDOJpibW86KG1XX',
#    'user': {'login': 'jneo8',
#     'id': 22070286,
#     'node_id': 'MDQ6VXNlcjIyMDcwMjg2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/22070286?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jneo8',
#     'html_url': 'https://github.com/jneo8',
#     'followers_url': 'https://api.github.com/users/jneo8/followers',
#     'following_url': 'https://api.github.com/users/jneo8/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jneo8/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jneo8/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jneo8/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jneo8/orgs',
#     'repos_url': 'https://api.github.com/users/jneo8/repos',
#     'events_url': 'https://api.github.com/users/jneo8/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jneo8/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'body': None,
#    'commit_id': '9358ec4e9eb021388231847c5f38d58137fd6951',
#    'submitted_at': '2024-09-20T01:55:44Z',
#    'state': 'commented',
#    'html_url': 'https://github.com/canonical/hardware-observer-operator/pull/319#pullrequestreview-2317047255',
#    'pull_request_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319',
#    'author_association': 'CONTRIBUTOR',
#    '_links': {'html': {'href': 'https://github.com/canonical/hardware-observer-operator/pull/319#pullrequestreview-2317047255'},
#     'pull_request': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319'}}},
#   'pull_request': {'url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319',
#    'id': 2079766989,
#    'node_id': 'PR_kwDOJpibW8579rnN',
#    'html_url': 'https://github.com/canonical/hardware-observer-operator/pull/319',
#    'diff_url': 'https://github.com/canonical/hardware-observer-operator/pull/319.diff',
#    'patch_url': 'https://github.com/canonical/hardware-observer-operator/pull/319.patch',
#    'issue_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/319',
#    'number': 319,
#    'state': 'open',
#    'locked': False,
#    'title': 'Add SnapExporter class and DCGM',
#    'user': {'login': 'gabrielcocenza',
#     'id': 23260991,
#     'node_id': 'MDQ6VXNlcjIzMjYwOTkx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/23260991?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/gabrielcocenza',
#     'html_url': 'https://github.com/gabrielcocenza',
#     'followers_url': 'https://api.github.com/users/gabrielcocenza/followers',
#     'following_url': 'https://api.github.com/users/gabrielcocenza/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/gabrielcocenza/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/gabrielcocenza/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/gabrielcocenza/subscriptions',
#     'organizations_url': 'https://api.github.com/users/gabrielcocenza/orgs',
#     'repos_url': 'https://api.github.com/users/gabrielcocenza/repos',
#     'events_url': 'https://api.github.com/users/gabrielcocenza/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/gabrielcocenza/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'body': '- Added the SnapExporter class that can be used for handle snap packages\r\n- Added the DCGMExporter that installs the DCGM exporter if detected NVIDIA GPUs\r\n- BaseExporter is a simple abstract class that has the required methods for an exporter\r\n- RendarableExporter is the legacy BaseExporter that contains the logic for exporters that are not snaped',
#    'created_at': '2024-09-18T23:45:55Z',
#    'updated_at': '2024-09-20T01:55:44Z',
#    'closed_at': None,
#    'merged_at': None,
#    'merge_commit_sha': 'ebe046903a482765bbcdf0793c58602ac081ba42',
#    'assignee': None,
#    'assignees': [],
#    'requested_reviewers': [{'login': 'Pjack',
#      'id': 1013484,
#      'node_id': 'MDQ6VXNlcjEwMTM0ODQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1013484?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Pjack',
#      'html_url': 'https://github.com/Pjack',
#      'followers_url': 'https://api.github.com/users/Pjack/followers',
#      'following_url': 'https://api.github.com/users/Pjack/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Pjack/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Pjack/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Pjack/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Pjack/orgs',
#      'repos_url': 'https://api.github.com/users/Pjack/repos',
#      'events_url': 'https://api.github.com/users/Pjack/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Pjack/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'aieri',
#      'id': 4036574,
#      'node_id': 'MDQ6VXNlcjQwMzY1NzQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4036574?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/aieri',
#      'html_url': 'https://github.com/aieri',
#      'followers_url': 'https://api.github.com/users/aieri/followers',
#      'following_url': 'https://api.github.com/users/aieri/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/aieri/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/aieri/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/aieri/subscriptions',
#      'organizations_url': 'https://api.github.com/users/aieri/orgs',
#      'repos_url': 'https://api.github.com/users/aieri/repos',
#      'events_url': 'https://api.github.com/users/aieri/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/aieri/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'samuelallan72',
#      'id': 9714796,
#      'node_id': 'U_kgDOAJQ8bA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9714796?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/samuelallan72',
#      'html_url': 'https://github.com/samuelallan72',
#      'followers_url': 'https://api.github.com/users/samuelallan72/followers',
#      'following_url': 'https://api.github.com/users/samuelallan72/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/samuelallan72/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/samuelallan72/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/samuelallan72/subscriptions',
#      'organizations_url': 'https://api.github.com/users/samuelallan72/orgs',
#      'repos_url': 'https://api.github.com/users/samuelallan72/repos',
#      'events_url': 'https://api.github.com/users/samuelallan72/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/samuelallan72/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'jneo8',
#      'id': 22070286,
#      'node_id': 'MDQ6VXNlcjIyMDcwMjg2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/22070286?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jneo8',
#      'html_url': 'https://github.com/jneo8',
#      'followers_url': 'https://api.github.com/users/jneo8/followers',
#      'following_url': 'https://api.github.com/users/jneo8/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jneo8/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jneo8/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jneo8/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jneo8/orgs',
#      'repos_url': 'https://api.github.com/users/jneo8/repos',
#      'events_url': 'https://api.github.com/users/jneo8/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jneo8/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'rgildein',
#      'id': 34167657,
#      'node_id': 'MDQ6VXNlcjM0MTY3NjU3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/34167657?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rgildein',
#      'html_url': 'https://github.com/rgildein',
#      'followers_url': 'https://api.github.com/users/rgildein/followers',
#      'following_url': 'https://api.github.com/users/rgildein/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rgildein/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rgildein/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rgildein/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rgildein/orgs',
#      'repos_url': 'https://api.github.com/users/rgildein/repos',
#      'events_url': 'https://api.github.com/users/rgildein/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rgildein/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'Deezzir',
#      'id': 55366304,
#      'node_id': 'MDQ6VXNlcjU1MzY2MzA0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/55366304?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Deezzir',
#      'html_url': 'https://github.com/Deezzir',
#      'followers_url': 'https://api.github.com/users/Deezzir/followers',
#      'following_url': 'https://api.github.com/users/Deezzir/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Deezzir/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Deezzir/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Deezzir/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Deezzir/orgs',
#      'repos_url': 'https://api.github.com/users/Deezzir/repos',
#      'events_url': 'https://api.github.com/users/Deezzir/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Deezzir/received_events',
#      'type': 'User',
#      'site_admin': False},
#     {'login': 'chanchiwai-ray',
#      'id': 72372217,
#      'node_id': 'MDQ6VXNlcjcyMzcyMjE3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72372217?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chanchiwai-ray',
#      'html_url': 'https://github.com/chanchiwai-ray',
#      'followers_url': 'https://api.github.com/users/chanchiwai-ray/followers',
#      'following_url': 'https://api.github.com/users/chanchiwai-ray/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chanchiwai-ray/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chanchiwai-ray/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chanchiwai-ray/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chanchiwai-ray/orgs',
#      'repos_url': 'https://api.github.com/users/chanchiwai-ray/repos',
#      'events_url': 'https://api.github.com/users/chanchiwai-ray/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chanchiwai-ray/received_events',
#      'type': 'User',
#      'site_admin': False}],
#    'requested_teams': [{'name': 'SolEng Reviewers',
#      'id': 9077967,
#      'node_id': 'T_kwDOAymYU84AioTP',
#      'slug': 'soleng-reviewers',
#      'description': '',
#      'privacy': 'closed',
#      'notification_setting': 'notifications_enabled',
#      'url': 'https://api.github.com/organizations/53057619/team/9077967',
#      'html_url': 'https://github.com/orgs/canonical/teams/soleng-reviewers',
#      'members_url': 'https://api.github.com/organizations/53057619/team/9077967/members{/member}',
#      'repositories_url': 'https://api.github.com/organizations/53057619/team/9077967/repos',
#      'permission': 'pull',
#      'parent': None}],
#    'labels': [],
#    'milestone': None,
#    'draft': False,
#    'commits_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319/commits',
#    'review_comments_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319/comments',
#    'review_comment_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/comments{/number}',
#    'comments_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/319/comments',
#    'statuses_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/statuses/97cc2e31b7312fc7a3745627b6fd7f763be44c16',
#    'head': {'label': 'gabrielcocenza:add-dcgm',
#     'ref': 'add-dcgm',
#     'sha': '97cc2e31b7312fc7a3745627b6fd7f763be44c16',
#     'user': {'login': 'gabrielcocenza',
#      'id': 23260991,
#      'node_id': 'MDQ6VXNlcjIzMjYwOTkx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/23260991?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gabrielcocenza',
#      'html_url': 'https://github.com/gabrielcocenza',
#      'followers_url': 'https://api.github.com/users/gabrielcocenza/followers',
#      'following_url': 'https://api.github.com/users/gabrielcocenza/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gabrielcocenza/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gabrielcocenza/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gabrielcocenza/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gabrielcocenza/orgs',
#      'repos_url': 'https://api.github.com/users/gabrielcocenza/repos',
#      'events_url': 'https://api.github.com/users/gabrielcocenza/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gabrielcocenza/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'repo': {'id': 759847221,
#      'node_id': 'R_kgDOLUpZNQ',
#      'name': 'hardware-observer-operator',
#      'full_name': 'gabrielcocenza/hardware-observer-operator',
#      'private': False,
#      'owner': {'login': 'gabrielcocenza',
#       'id': 23260991,
#       'node_id': 'MDQ6VXNlcjIzMjYwOTkx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/23260991?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gabrielcocenza',
#       'html_url': 'https://github.com/gabrielcocenza',
#       'followers_url': 'https://api.github.com/users/gabrielcocenza/followers',
#       'following_url': 'https://api.github.com/users/gabrielcocenza/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gabrielcocenza/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gabrielcocenza/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gabrielcocenza/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gabrielcocenza/orgs',
#       'repos_url': 'https://api.github.com/users/gabrielcocenza/repos',
#       'events_url': 'https://api.github.com/users/gabrielcocenza/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gabrielcocenza/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'html_url': 'https://github.com/gabrielcocenza/hardware-observer-operator',
#      'description': 'A charm to setup prometheus exporter for IPMI, RedFish and RAID devices from different vendors. ',
#      'fork': True,
#      'url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator',
#      'forks_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/forks',
#      'keys_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/teams',
#      'hooks_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/hooks',
#      'issue_events_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/events',
#      'assignees_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/tags',
#      'blobs_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/languages',
#      'stargazers_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/stargazers',
#      'contributors_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/contributors',
#      'subscribers_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/subscribers',
#      'subscription_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/subscription',
#      'commits_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/merges',
#      'archive_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/downloads',
#      'issues_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/gabrielcocenza/hardware-observer-operator/deployments',
#      'created_at': '2024-02-19T12:59:41Z',
#      'updated_at': '2024-09-06T18:24:41Z',
#      'pushed_at': '2024-09-19T21:59:30Z',
#      'git_url': 'git://github.com/gabrielcocenza/hardware-observer-operator.git',
#      'ssh_url': 'git@github.com:gabrielcocenza/hardware-observer-operator.git',
#      'clone_url': 'https://github.com/gabrielcocenza/hardware-observer-operator.git',
#      'svn_url': 'https://github.com/gabrielcocenza/hardware-observer-operator',
#      'homepage': '',
#      'size': 515,
#      'stargazers_count': 0,
#      'watchers_count': 0,
#      'language': 'Python',
#      'has_issues': False,
#      'has_projects': True,
#      'has_downloads': True,
#      'has_wiki': False,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 0,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 0,
#      'license': {'key': 'apache-2.0',
#       'name': 'Apache License 2.0',
#       'spdx_id': 'Apache-2.0',
#       'url': 'https://api.github.com/licenses/apache-2.0',
#       'node_id': 'MDc6TGljZW5zZTI='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 0,
#      'open_issues': 0,
#      'watchers': 0,
#      'default_branch': 'main'}},
#    'base': {'label': 'canonical:main',
#     'ref': 'main',
#     'sha': 'd420c6364551fe15021b3ac3fdfb28d9ed41b906',
#     'user': {'login': 'canonical',
#      'id': 53057619,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUzMDU3NjE5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/53057619?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/canonical',
#      'html_url': 'https://github.com/canonical',
#      'followers_url': 'https://api.github.com/users/canonical/followers',
#      'following_url': 'https://api.github.com/users/canonical/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/canonical/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/canonical/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/canonical/subscriptions',
#      'organizations_url': 'https://api.github.com/users/canonical/orgs',
#      'repos_url': 'https://api.github.com/users/canonical/repos',
#      'events_url': 'https://api.github.com/users/canonical/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/canonical/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'repo': {'id': 647535451,
#      'node_id': 'R_kgDOJpibWw',
#      'name': 'hardware-observer-operator',
#      'full_name': 'canonical/hardware-observer-operator',
#      'private': False,
#      'owner': {'login': 'canonical',
#       'id': 53057619,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUzMDU3NjE5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/53057619?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/canonical',
#       'html_url': 'https://github.com/canonical',
#       'followers_url': 'https://api.github.com/users/canonical/followers',
#       'following_url': 'https://api.github.com/users/canonical/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/canonical/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/canonical/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/canonical/subscriptions',
#       'organizations_url': 'https://api.github.com/users/canonical/orgs',
#       'repos_url': 'https://api.github.com/users/canonical/repos',
#       'events_url': 'https://api.github.com/users/canonical/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/canonical/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'html_url': 'https://github.com/canonical/hardware-observer-operator',
#      'description': 'A charm to setup prometheus exporter for IPMI, RedFish and RAID devices from different vendors.',
#      'fork': False,
#      'url': 'https://api.github.com/repos/canonical/hardware-observer-operator',
#      'forks_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/forks',
#      'keys_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/keys{/key_id}',
#      'collaborators_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/collaborators{/collaborator}',
#      'teams_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/teams',
#      'hooks_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/hooks',
#      'issue_events_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/events{/number}',
#      'events_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/events',
#      'assignees_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/assignees{/user}',
#      'branches_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/branches{/branch}',
#      'tags_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/tags',
#      'blobs_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/git/blobs{/sha}',
#      'git_tags_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/git/tags{/sha}',
#      'git_refs_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/git/refs{/sha}',
#      'trees_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/git/trees{/sha}',
#      'statuses_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/statuses/{sha}',
#      'languages_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/languages',
#      'stargazers_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/stargazers',
#      'contributors_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/contributors',
#      'subscribers_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/subscribers',
#      'subscription_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/subscription',
#      'commits_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/commits{/sha}',
#      'git_commits_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/git/commits{/sha}',
#      'comments_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/comments{/number}',
#      'issue_comment_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/comments{/number}',
#      'contents_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/contents/{+path}',
#      'compare_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/compare/{base}...{head}',
#      'merges_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/merges',
#      'archive_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/{archive_format}{/ref}',
#      'downloads_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/downloads',
#      'issues_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues{/number}',
#      'pulls_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls{/number}',
#      'milestones_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/milestones{/number}',
#      'notifications_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/notifications{?since,all,participating}',
#      'labels_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/labels{/name}',
#      'releases_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/releases{/id}',
#      'deployments_url': 'https://api.github.com/repos/canonical/hardware-observer-operator/deployments',
#      'created_at': '2023-05-31T01:58:11Z',
#      'updated_at': '2024-09-17T19:15:24Z',
#      'pushed_at': '2024-09-19T21:06:04Z',
#      'git_url': 'git://github.com/canonical/hardware-observer-operator.git',
#      'ssh_url': 'git@github.com:canonical/hardware-observer-operator.git',
#      'clone_url': 'https://github.com/canonical/hardware-observer-operator.git',
#      'svn_url': 'https://github.com/canonical/hardware-observer-operator',
#      'homepage': '',
#      'size': 411,
#      'stargazers_count': 7,
#      'watchers_count': 7,
#      'language': 'Python',
#      'has_issues': True,
#      'has_projects': False,
#      'has_downloads': False,
#      'has_wiki': False,
#      'has_pages': False,
#      'has_discussions': False,
#      'forks_count': 14,
#      'mirror_url': None,
#      'archived': False,
#      'disabled': False,
#      'open_issues_count': 36,
#      'license': {'key': 'apache-2.0',
#       'name': 'Apache License 2.0',
#       'spdx_id': 'Apache-2.0',
#       'url': 'https://api.github.com/licenses/apache-2.0',
#       'node_id': 'MDc6TGljZW5zZTI='},
#      'allow_forking': True,
#      'is_template': False,
#      'web_commit_signoff_required': False,
#      'topics': [],
#      'visibility': 'public',
#      'forks': 14,
#      'open_issues': 36,
#      'watchers': 7,
#      'default_branch': 'main'}},
#    '_links': {'self': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319'},
#     'html': {'href': 'https://github.com/canonical/hardware-observer-operator/pull/319'},
#     'issue': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/319'},
#     'comments': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/issues/319/comments'},
#     'review_comments': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319/comments'},
#     'review_comment': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/comments{/number}'},
#     'commits': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/pulls/319/commits'},
#     'statuses': {'href': 'https://api.github.com/repos/canonical/hardware-observer-operator/statuses/97cc2e31b7312fc7a3745627b6fd7f763be44c16'}},
#    'author_association': 'MEMBER',
#    'auto_merge': None,
#    'active_lock_reason': None}},
#  'public': True,
#  'created_at': '2024-09-20T01:55:45Z',
#  'org': {'id': 53057619,
#   'login': 'canonical',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/canonical',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/53057619?'}}

# %%
type(data)
# Out:
# list

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %%
import pandas as pd
df = pd.DataFrame(data)  # list to dataframe
df
# Out:
#              id                    type  \
# 0   42101241571  PullRequestReviewEvent
# 1   42101241569               ForkEvent
# 2   42101241552               PushEvent
# 3   42101241549  PullRequestReviewEvent
# 4   42101241557             DeleteEvent
# 5   42101241556             DeleteEvent
# 6   42101241538               PushEvent
# 7   42101241551             MemberEvent
# 8   42101241534               PushEvent
# 9   42101241540               PushEvent
# 10  42101241542               PushEvent
# 11  42101241527               PushEvent
# 12  42101241526               PushEvent
# 13  42101241530               PushEvent
# 14  42101241528             DeleteEvent
# 15  42101241520               PushEvent
# 16  42101241512               PushEvent
# 17  42101241514              WatchEvent
# 18  42101241503        PullRequestEvent
# 19  42101241506             IssuesEvent
# 20  42101241490               PushEvent
# 21  42101241484               PushEvent
# 22  42101241510             DeleteEvent
# 23  42101241492             CreateEvent
# 24  42101241479               PushEvent
# 25  42101241485             DeleteEvent
# 26  42101241464               PushEvent
# 27  42101241472               PushEvent
# 28  42101241470             DeleteEvent
# 29  42101241463               PushEvent
#
#                                                 actor  \
# 0   {'id': 22070286, 'login': 'jneo8', 'display_lo...
# 1   {'id': 58833581, 'login': 'LDF-ling', 'display...
# 2   {'id': 180817924, 'login': 'frdpzk4', 'display...
# 3   {'id': 856316, 'login': 'snnn', 'display_login...
# 4   {'id': 8676405, 'login': 'williamcanin', 'disp...
# 5   {'id': 85991289, 'login': 'vipshmily', 'displa...
# 6   {'id': 5792218, 'login': 'qcjxberin', 'display...
# 7   {'id': 115493294, 'login': 'Avin-7', 'display_...
# 8   {'id': 173535095, 'login': 'frdpzk2', 'display...
# 9   {'id': 58163429, 'login': 'YelloooBlue', 'disp...
# 10  {'id': 77010142, 'login': 'jeryjs', 'display_l...
# 11  {'id': 55595719, 'login': 'liangkangnan', 'dis...
# 12  {'id': 82980802, 'login': 'josephtjohnson', 'd...
# 13  {'id': 65212910, 'login': 'Hall-1910', 'displa...
# 14  {'id': 1589480, 'login': 'BrewTestBot', 'displ...
# 15  {'id': 41898282, 'login': 'github-actions[bot]...
# 16  {'id': 180258059, 'login': 'acevsok', 'display...
# 17  {'id': 38682686, 'login': 'ChaoGoing', 'displa...
# 18  {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 19  {'id': 124675, 'login': 'hgezim', 'display_log...
# 20  {'id': 171133247, 'login': 'Chang-ChungWei', '...
# 21  {'id': 16675675, 'login': 'mkarmark', 'display...
# 22  {'id': 170966, 'login': 'waltersf', 'display_l...
# 23  {'id': 9782008, 'login': 'sarbagyastha', 'disp...
# 24  {'id': 129989075, 'login': 'Gopher8484', 'disp...
# 25  {'id': 448694, 'login': 'randallb', 'display_l...
# 26  {'id': 41898282, 'login': 'github-actions[bot]...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 41898282, 'login': 'github-actions[bot]...
# 29  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                  repo  \
# 0   {'id': 647535451, 'name': 'canonical/hardware-...
# 1   {'id': 578822531, 'name': 'localsend/localsend...
# 2   {'id': 854006625, 'name': 'frdpzk4/ppub', 'url...
# 3   {'id': 156939672, 'name': 'microsoft/onnxrunti...
# 4   {'id': 860182211, 'name': 'williamcanin/cargo-...
# 5   {'id': 445564075, 'name': 'vipshmily/Padavan-b...
# 6   {'id': 844516185, 'name': 'PeiKeSmart/DH.NRemo...
# 7   {'id': 844051004, 'name': 'Avin-7/course-listi...
# 8   {'id': 818567109, 'name': 'frdpzk2/ppub', 'url...
# 9   {'id': 860192330, 'name': 'YelloooBlue-Group/o...
# 10  {'id': 708598879, 'name': 'jeryjs/Feed-Formula...
# 11  {'id': 844382698, 'name': 'liangkangnan/Hazard...
# 12  {'id': 844951976, 'name': 'josephtjohnson/CSC7...
# 13  {'id': 222505696, 'name': 'brand22/d3', 'url':...
# 14  {'id': 52855516, 'name': 'Homebrew/homebrew-co...
# 15  {'id': 402685263, 'name': 'kull-boii/kull-boii...
# 16  {'id': 859201187, 'name': 'acevsok/acevs.githu...
# 17  {'id': 847885, 'name': 'mathjax/MathJax', 'url...
# 18  {'id': 642334411, 'name': 'SunsetMkt/kigurumi'...
# 19  {'id': 813405111, 'name': 'TarteelAI/quranic-u...
# 20  {'id': 857250578, 'name': 'Chang-ChungWei/Mach...
# 21  {'id': 860191868, 'name': 'static-web-apps-tes...
# 22  {'id': 68124762, 'name': 'eubr-bigsea/juicer',...
# 23  {'id': 178110536, 'name': 'sarbagyastha/flutte...
# 24  {'id': 624310976, 'name': 'Gopher8484/msoffice...
# 25  {'id': 783462914, 'name': 'bolt-foundry/bolt-f...
# 26  {'id': 307998199, 'name': 'poscat0x04/nix-repo...
# 27  {'id': 396043059, 'name': 'gphg/Main', 'url': ...
# 28  {'id': 660746837, 'name': 'uniget-org/tools', ...
# 29  {'id': 283239551, 'name': 'ipstreet312/freeipt...
#
#                                               payload  public  \
# 0   {'action': 'created', 'review': {'id': 2317047...    True
# 1   {'forkee': {'id': 860193299, 'node_id': 'R_kgD...    True
# 2   {'repository_id': 854006625, 'push_id': 203251...    True
# 3   {'action': 'created', 'review': {'id': 2317045...    True
# 4   {'ref': 'v0.1.0', 'ref_type': 'tag', 'pusher_t...    True
# 5   {'ref': 'main4', 'ref_type': 'branch', 'pusher...    True
# 6   {'repository_id': 844516185, 'push_id': 203251...    True
# 7   {'member': {'login': 'Astern-Pinto', 'id': 158...    True
# 8   {'repository_id': 818567109, 'push_id': 203251...    True
# 9   {'repository_id': 860192330, 'push_id': 203251...    True
# 10  {'repository_id': 708598879, 'push_id': 203251...    True
# 11  {'repository_id': 844382698, 'push_id': 203251...    True
# 12  {'repository_id': 844951976, 'push_id': 203251...    True
# 13  {'repository_id': 222505696, 'push_id': 203251...    True
# 14  {'ref': 'bump-millet-0.14.7', 'ref_type': 'bra...    True
# 15  {'repository_id': 402685263, 'push_id': 203251...    True
# 16  {'repository_id': 859201187, 'push_id': 203251...    True
# 17                              {'action': 'started'}    True
# 18  {'action': 'closed', 'number': 9, 'pull_reques...    True
# 19  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 20  {'repository_id': 857250578, 'push_id': 203251...    True
# 21  {'repository_id': 860191868, 'push_id': 203251...    True
# 22  {'ref': 'dependabot/pip/pyarrow-14.0.1', 'ref_...    True
# 23  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 24  {'repository_id': 624310976, 'push_id': 203251...    True
# 25  {'ref': 'pr713', 'ref_type': 'branch', 'pusher...    True
# 26  {'repository_id': 307998199, 'push_id': 203251...    True
# 27  {'repository_id': 396043059, 'push_id': 203251...    True
# 28  {'ref': 'renovate/aws-aws-cli-2.17.x', 'ref_ty...    True
# 29  {'repository_id': 283239551, 'push_id': 203251...    True
#
#               created_at                                                org
# 0   2024-09-20T01:55:45Z  {'id': 53057619, 'login': 'canonical', 'gravat...
# 1   2024-09-20T01:55:45Z  {'id': 120677616, 'login': 'localsend', 'grava...
# 2   2024-09-20T01:55:45Z                                                NaN
# 3   2024-09-20T01:55:45Z  {'id': 6154722, 'login': 'microsoft', 'gravata...
# 4   2024-09-20T01:55:45Z                                                NaN
# 5   2024-09-20T01:55:45Z                                                NaN
# 6   2024-09-20T01:55:45Z  {'id': 120533926, 'login': 'PeiKeSmart', 'grav...
# 7   2024-09-20T01:55:45Z                                                NaN
# 8   2024-09-20T01:55:45Z                                                NaN
# 9   2024-09-20T01:55:45Z  {'id': 182181650, 'login': 'YelloooBlue-Group'...
# 10  2024-09-20T01:55:45Z                                                NaN
# 11  2024-09-20T01:55:45Z                                                NaN
# 12  2024-09-20T01:55:45Z                                                NaN
# 13  2024-09-20T01:55:45Z                                                NaN
# 14  2024-09-20T01:55:45Z  {'id': 1503512, 'login': 'Homebrew', 'gravatar...
# 15  2024-09-20T01:55:45Z                                                NaN
# 16  2024-09-20T01:55:45Z                                                NaN
# 17  2024-09-20T01:55:45Z  {'id': 252187, 'login': 'mathjax', 'gravatar_i...
# 18  2024-09-20T01:55:45Z                                                NaN
# 19  2024-09-20T01:55:45Z  {'id': 43034731, 'login': 'TarteelAI', 'gravat...
# 20  2024-09-20T01:55:45Z                                                NaN
# 21  2024-09-20T01:55:45Z  {'id': 96167003, 'login': 'static-web-apps-tes...
# 22  2024-09-20T01:55:45Z  {'id': 18013593, 'login': 'eubr-bigsea', 'grav...
# 23  2024-09-20T01:55:45Z                                                NaN
# 24  2024-09-20T01:55:45Z                                                NaN
# 25  2024-09-20T01:55:45Z  {'id': 130794054, 'login': 'bolt-foundry', 'gr...
# 26  2024-09-20T01:55:45Z                                                NaN
# 27  2024-09-20T01:55:45Z                                                NaN
# 28  2024-09-20T01:55:45Z  {'id': 137505866, 'login': 'uniget-org', 'grav...
# 29  2024-09-20T01:55:45Z                                                NaN

# %%
for content in df['actor'][:10]:
    print(content)
# Out:
# {'id': 22070286, 'login': 'jneo8', 'display_login': 'jneo8', 'gravatar_id': '', 'url': 'https://api.github.com/users/jneo8', 'avatar_url': 'https://avatars.githubusercontent.com/u/22070286?'}
# {'id': 58833581, 'login': 'LDF-ling', 'display_login': 'LDF-ling', 'gravatar_id': '', 'url': 'https://api.github.com/users/LDF-ling', 'avatar_url': 'https://avatars.githubusercontent.com/u/58833581?'}
# {'id': 180817924, 'login': 'frdpzk4', 'display_login': 'frdpzk4', 'gravatar_id': '', 'url': 'https://api.github.com/users/frdpzk4', 'avatar_url': 'https://avatars.githubusercontent.com/u/180817924?'}
# {'id': 856316, 'login': 'snnn', 'display_login': 'snnn', 'gravatar_id': '', 'url': 'https://api.github.com/users/snnn', 'avatar_url': 'https://avatars.githubusercontent.com/u/856316?'}
# {'id': 8676405, 'login': 'williamcanin', 'display_login': 'williamcanin', 'gravatar_id': '', 'url': 'https://api.github.com/users/williamcanin', 'avatar_url': 'https://avatars.githubusercontent.com/u/8676405?'}
# {'id': 85991289, 'login': 'vipshmily', 'display_login': 'vipshmily', 'gravatar_id': '', 'url': 'https://api.github.com/users/vipshmily', 'avatar_url': 'https://avatars.githubusercontent.com/u/85991289?'}
# {'id': 5792218, 'login': 'qcjxberin', 'display_login': 'qcjxberin', 'gravatar_id': '', 'url': 'https://api.github.com/users/qcjxberin', 'avatar_url': 'https://avatars.githubusercontent.com/u/5792218?'}
# {'id': 115493294, 'login': 'Avin-7', 'display_login': 'Avin-7', 'gravatar_id': '', 'url': 'https://api.github.com/users/Avin-7', 'avatar_url': 'https://avatars.githubusercontent.com/u/115493294?'}
# {'id': 173535095, 'login': 'frdpzk2', 'display_login': 'frdpzk2', 'gravatar_id': '', 'url': 'https://api.github.com/users/frdpzk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/173535095?'}
# {'id': 58163429, 'login': 'YelloooBlue', 'display_login': 'YelloooBlue', 'gravatar_id': '', 'url': 'https://api.github.com/users/YelloooBlue', 'avatar_url': 'https://avatars.githubusercontent.com/u/58163429?'}

# %% [markdown]
# >> ### json파일 읽고 tree 구조로 보는 방법

# %%
import json

data = {
    "name": "John",
    "age": 30,
    "city": "New York"
}

formatted_json = json.dumps(data, indent=2)  # 들여쓰기하면 보기가 좋음
print(formatted_json)
# Out:
# {
#   "name": "John",
#   "age": 30,
#   "city": "New York"
# }

# %%
data = [{
    "name": "John",
    "age": 30,
    "city": "New York"
}]

formatted_json = json.dumps(data, indent=2)  # 들여쓰기하면 보기가 좋음
print(formatted_json)
# Out:
# [
#   {
#     "name": "John",
#     "age": 30,
#     "city": "New York"
#   }
# ]

# %% [markdown]
# >> ### https://jsonviewer.stack.hu/
# - 크롬확장프로그램으로 설치하여 확인하기
# - TEXT 탭에 JSON 데이터를 입력하고 Viewer 탭으로 이동

# %%
# Pretty-print the list of dictionaries (JSON data)
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "name": "John",
#     "age": 30,
#     "city": "New York"
#   }
# ]

# %%
import pprint
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(data)
# Out:
# [{'age': 30, 'city': 'New York', 'name': 'John'}]
